# %% [markdown]
# Part d)

# %% [markdown]
#  -The variable item cannot have NaN as an item in objective 8
#
#  - The variable item cannot have an unkown item in objective 6

# %% [markdown]
# - There is an error in the variables of total spent

# %% [markdown]
# - There is an error in the variable of payment method in the unkown ,NaN and error

# %% [markdown]
#  -There is an erro in the location of it bein unkown and NaN

# %% [markdown]
# -The quantity, price and total spent should be integers instead of strings
