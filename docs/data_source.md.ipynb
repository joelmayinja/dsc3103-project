# %% [markdown]
# Part b)

# %% [markdown]
# I)

# %% [markdown]
# It is a structured dataset
#
# This is because the variables are organised accordingly.

# %% [markdown]
# II)

# %% [markdown]
# Item - Represents the items that the objective is attaining
#
# Quantity - Represents the amount of the item the objectve is getting
#
# Price Per Unit- Represents the prices of each item in relation to the quantity taken
#
# Total Spent- Represets the total amount paid for the all the quanties in total for the objective
#
# Payment Method- Reprsents the means for paying eg credit card or cash
#
# Location - Represnts the loction where the meal will be had from either take away or inside the store
#
# Transaction Date -Represents the date when the transaction happened

# %% [markdown]
# III)

# %% [markdown]
# The target variable would be Total spent

# %% [markdown]
# Feature variables -Price per Unit, Quantity,Item,Location,Transaction date
